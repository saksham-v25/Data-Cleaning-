# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham-v25/ML/blob/main/star_wars_analysis/star_wars_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas requests

# %%
import requests

# %%
data=requests.get("https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbXB1cl8tZFh6ZUdQM2hBTmhSVHlGLVB2dHk2d3xBQ3Jtc0tseHBtWndlLUQ3U0lqUG5zRUFma0J3TFRyQmo5dW9qdm5nWjNLdjl2N0c0X3BQNFRhMnBiYjI2TzF3NWZ0TUxpd0dodmFYS0VCNUc1S2pmeUxxR0dUUjZENUdsTTIwbFpmYy1QTVJsb1oxM01wc1RXcw&q=https%3A%2F%2Fgithub.com%2Ffivethirtyeight%2Fdata%2Fblob%2Fmaster%2Fstar-wars-survey%2FStarWars.csv&v=IVGI8xZnFxY")

# %%
with open('starwars.csv','w+') as f:
  f.write(data.text)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/starwars.csv")

# %%
df
# Out:
# Empty DataFrame
# ...

# %%
df.shape
# Out:
# (0, 16)
